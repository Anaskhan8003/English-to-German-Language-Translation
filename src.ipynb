# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
import torch
import os
import sentencepiece as spm
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import math

# %%
dataset = load_dataset("opus100", "de-en")

train_data = dataset["train"].shuffle(seed=42).select(range(10000))

src_lang = "en"
tgt_lang = "de"

# %%
def is_valid(example):
    src = example["translation"][src_lang]
    tgt = example["translation"][tgt_lang]

    if src.startswith("[{") or tgt.startswith("[{"):
        return False
    if len(src.split()) < 3 or len(tgt.split()) < 3:
        return False
    return True

train_data = train_data.filter(is_valid)

# %%
df = train_data.to_pandas()
df["en"] = df["translation"].apply(lambda x: x["en"])
df["de"] = df["translation"].apply(lambda x: x["de"])
df = df.drop(columns=["translation"])

# %%
df["en"].to_csv("train.en", index=False, header=False)
df["de"].to_csv("train.de", index=False, header=False)

# %%
spm.SentencePieceTrainer.train(
    input="train.en,train.de",
    model_prefix="bpe",
    vocab_size=8000,
    model_type="bpe",
    bos_id=1,
    eos_id=2,
    pad_id=3,
    unk_id=0
)
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: train.en
#   input: train.de
#   input_format:
#   model_prefix: bpe
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: 3
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: train.en
# trainer_interface.cc(186) LOG(INFO) Loading corpus: train.de
# trainer_interface.cc(411) LOG(INFO) Loaded all 16660 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=1372600
# trainer_interface.cc(552) LOG(INFO) Done: 99.9507% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=114
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999508
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 16660 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 16660
# trainer_interface.cc(611) LOG(INFO) Done! 55519
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=25484 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7247 size=20 all=4159 active=2221 piece=or
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3979 size=40 all=5333 active=3395 piece=▁n
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2811 size=60 all=6474 active=4536 piece=ro
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2272 size=80 all=7463 active=5525 piece=ter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1769 size=100 all=8791 active=6853 piece=am
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1765 min_freq=152
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1457 size=120 all=10260 active=2342 piece=ab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1167 size=140 all=11660 active=3742 piece=▁das
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=990 size=160 all=12761 active=4843 piece=ith
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=835 size=180 all=13700 active=5782 piece=▁für
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=741 size=200 all=14516 active=6598 piece=ht
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=738 min_freq=128
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=650 size=220 all=15670 active=2110 piece=und
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=582 size=240 all=16551 active=2991 piece=▁Un
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=537 size=260 all=17429 active=3869 piece=▁wer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=488 size=280 all=18216 active=4656 piece=hen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=452 size=300 all=19025 active=5465 piece=...
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=450 min_freq=109
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=410 size=320 all=20034 active=1988 piece=enn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=383 size=340 all=20657 active=2611 piece=▁war
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=353 size=360 all=21622 active=3576 piece=ia
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=321 size=380 all=22377 active=4331 piece=▁man
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=306 size=400 all=22998 active=4952 piece=ät
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=306 min_freq=86
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=280 size=420 all=23674 active=1787 piece=ry
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=265 size=440 all=24514 active=2627 piece=▁sp
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=256 size=460 all=25290 active=3403 piece=▁12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=243 size=480 all=25869 active=3982 piece=fü
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=230 size=500 all=26393 active=4506 piece=ian
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=230 min_freq=71
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=219 size=520 all=26911 active=1775 piece=ook
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=211 size=540 all=27344 active=2208 piece=▁there
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=560 all=27816 active=2680 piece=land
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=192 size=580 all=28476 active=3340 piece=ally
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=6480 all=71270 active=3605 piece=▁Agreement
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=6500 all=71264 active=3599 piece=▁considered
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6520 all=71268 active=3568 piece=/5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6540 all=71388 active=3688 piece=“,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6560 all=71521 active=3821 piece=hnt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6580 all=71610 active=3910 piece=▁il
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6600 all=71665 active=3965 piece=dest
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6620 all=71802 active=3714 piece=oper
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6640 all=71887 active=3799 piece=▁Bis
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6660 all=71947 active=3859 piece=▁hid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6680 all=72018 active=3930 piece=oster
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6700 all=72079 active=3991 piece=▁Frem
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6720 all=72123 active=3646 piece=▁born
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6740 all=72154 active=3677 piece=▁thus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6760 all=72225 active=3748 piece=stellt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6780 all=72256 active=3779 piece=▁Neben
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6800 all=72269 active=3792 piece=▁lived
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6820 all=72296 active=3641 piece=istrict
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6840 all=72362 active=3707 piece=▁Stelle
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6860 all=72362 active=3707 piece=▁gelten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6880 all=72361 active=3706 piece=atellite
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6900 all=72400 active=3745 piece=▁explain
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6920 all=72403 active=3623 piece=▁written
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6940 all=72400 active=3620 piece=▁personal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6960 all=72388 active=3608 piece=▁efficient
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=6980 all=72393 active=3613 piece=▁Environment
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7000 all=72430 active=3650 piece=81
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7020 all=72533 active=3715 piece=###
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7040 all=72647 active=3829 piece=gie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7060 all=72782 active=3964 piece=ühm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7080 all=72823 active=4005 piece=Post
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7100 all=72913 active=4095 piece=hung
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7120 all=73021 active=3746 piece=rick
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7140 all=73084 active=3809 piece=▁17.
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7160 all=73121 active=3846 piece=▁Sen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7180 all=73172 active=3897 piece=▁vac
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7200 all=73261 active=3986 piece=heben
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7220 all=73361 active=3756 piece=wagen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7240 all=73421 active=3816 piece=▁Link
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7260 all=73465 active=3860 piece=▁drug
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7280 all=73488 active=3883 piece=▁self
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7300 all=73547 active=3942 piece=kunfts
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7320 all=73624 active=3744 piece=▁Anton
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7340 all=73639 active=3759 piece=▁essen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7360 all=73653 active=3773 piece=▁space
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7380 all=73694 active=3814 piece=lemente
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7400 all=73735 active=3855 piece=▁announ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7420 all=73752 active=3700 piece=▁giving
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7440 all=73747 active=3695 piece=▁sprach
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7460 all=73760 active=3708 piece=▁Milliar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7480 all=73763 active=3711 piece=▁genannt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7500 all=73755 active=3703 piece=▁suggest
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7520 all=73768 active=3698 piece=▁beschäft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7540 all=73764 active=3694 piece=▁sozialen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7560 all=73765 active=3695 piece=▁specified
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=7580 all=73753 active=3683 piece=▁Universität
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7600 all=73750 active=3680 piece=54
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7620 all=73857 active=3787 piece=án
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7640 all=73964 active=3894 piece=Mal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7660 all=74059 active=3989 piece=mpt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7680 all=74155 active=4085 piece=▁38
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7700 all=74199 active=4129 piece=Come
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7720 all=74286 active=3797 piece=ifer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7740 all=74370 active=3881 piece=rufe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7760 all=74406 active=3917 piece=▁Ere
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7780 all=74454 active=3965 piece=▁amb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7800 all=74511 active=4022 piece=aison
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7820 all=74593 active=3804 piece=kauft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7840 all=74655 active=3866 piece=▁Cast
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7860 all=74682 active=3893 piece=▁WLAN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=7880 all=74714 active=3925 piece=▁fand
# trainer_interface.cc(689) LOG(INFO) Saving model: bpe.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: bpe.vocab

# %%
sp = spm.SentencePieceProcessor()
sp.load("bpe.model")

PAD_ID = sp.pad_id() 
BOS_ID = sp.bos_id()
EOS_ID = sp.eos_id()
VOCAB_SIZE = sp.get_piece_size()

# %%
src_ids = []
tgt_ids = []

for _, row in df.iterrows():
    src = [sp.bos_id()] + sp.encode(row["en"], out_type=int) + [sp.eos_id()]
    tgt = [sp.bos_id()] + sp.encode(row["de"], out_type=int) + [sp.eos_id()]
    src_ids.append(src)
    tgt_ids.append(tgt)

# %%
print(src_ids[0])
print(sp.decode(src_ids[0][1:-1]))
# Out:
# [1, 61, 1991, 502, 1017, 2747, 2064, 2927, 31, 303, 2]
# 1 x Spider Straps System f...

# %%
MAX_LEN = 128

class TranslationDataset(Dataset):
    def __init__(self, src, tgt):
        self.src = src
        self.tgt = tgt

    def __len__(self):
        return len(self.src)

    def __getitem__(self, idx):
        src = self.src[idx][:MAX_LEN]
        tgt = self.tgt[idx][:MAX_LEN]

        src += [sp.pad_id()] * (MAX_LEN - len(src))
        tgt += [sp.pad_id()] * (MAX_LEN - len(tgt))

        return torch.tensor(src), torch.tensor(tgt)

# %%
dataset = TranslationDataset(src_ids, tgt_ids)

train_loader = DataLoader(
    dataset,
    batch_size=32,
    shuffle=True
)

# %%
s, t = next(iter(train_loader))
print(s.shape, t.shape)
# Out:
# torch.Size([32, 128]) torch.Size([32, 128])

# %%
def create_pad_mask(seq, pad_id):
    return (seq != pad_id).unsqueeze(1).unsqueeze(2)

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads, masked=False):
        super().__init__()
        assert d_model % n_heads == 0

        self.d_k = d_model // n_heads
        self.n_heads = n_heads
        self.masked = masked

        self.W_q = nn.Linear(d_model, d_model, bias=False)
        self.W_k = nn.Linear(d_model, d_model, bias=False)
        self.W_v = nn.Linear(d_model, d_model, bias=False)
        self.W_o = nn.Linear(d_model, d_model, bias=False)

    def forward(self, q, k, v, pad_mask=None):
        B, Tq, D = q.shape
        B, Tk, D = k.shape
        B, Tv, D = v.shape

        Q = self.W_q(q).view(B, Tq, self.n_heads, self.d_k).transpose(1, 2)
        K = self.W_k(k).view(B, Tk, self.n_heads, self.d_k).transpose(1, 2)
        V = self.W_v(v).view(B, Tv, self.n_heads, self.d_k).transpose(1, 2)

        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        if self.masked:
            causal = torch.tril(torch.ones(Tq, Tk)).to(q.device)
            scores = scores.masked_fill(causal == 0, float("-inf"))

        if pad_mask is not None:
            scores = scores.masked_fill(pad_mask == 0, float("-inf"))

        attn = torch.softmax(scores, dim=-1)
        out = torch.matmul(attn, V)

        out = out.transpose(1, 2).contiguous().view(B, Tq, D)
        return self.W_o(out)

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.attn = MultiHeadAttention(d_model, n_heads)
        self.norm1 = nn.LayerNorm(d_model)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x, src_mask):
        x = self.norm1(x + self.attn(x, x, x, src_mask))
        x = self.norm2(x + self.ffn(x))
        return x

# %%
class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads, masked=True)
        self.cross_attn = MultiHeadAttention(d_model, n_heads)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.norm3 = nn.LayerNorm(d_model)

    def forward(self, x, enc_out, src_mask, tgt_mask):
        x = self.norm1(x + self.self_attn(x, x, x, tgt_mask))
        x = self.norm2(x + self.cross_attn(x, enc_out, enc_out, src_mask))
        x = self.norm3(x + self.ffn(x))
        return x

# %%
class Transformer(nn.Module):
    def __init__(self, vocab_size, d_model=256, n_heads=4, n_layers=3, d_ff=512, max_len=512):
        super().__init__()
        self.tok_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(max_len, d_model)

        self.encoders = nn.ModuleList([
            EncoderLayer(d_model, n_heads, d_ff) for _ in range(n_layers)
        ])
        self.decoders = nn.ModuleList([
            DecoderLayer(d_model, n_heads, d_ff) for _ in range(n_layers)
        ])

        self.fc_out = nn.Linear(d_model, vocab_size)

    def forward(self, src_ids, tgt_ids):
        B, S = src_ids.shape
        _, T = tgt_ids.shape

        src_mask = create_pad_mask(src_ids, PAD_ID)
        tgt_mask = create_pad_mask(tgt_ids, PAD_ID)

        src_pos = torch.arange(S).to(src_ids.device)
        tgt_pos = torch.arange(T).to(tgt_ids.device)

        src = self.tok_emb(src_ids) + self.pos_emb(src_pos)
        tgt = self.tok_emb(tgt_ids) + self.pos_emb(tgt_pos)

        for enc in self.encoders:
            src = enc(src, src_mask)

        for dec in self.decoders:
            tgt = dec(tgt, src, src_mask, tgt_mask)

        return self.fc_out(tgt)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
my_model = Transformer(
    vocab_size=VOCAB_SIZE,
    d_model=256,
    n_heads=4,
    n_layers=3,
    d_ff=512,
    max_len=512
).to(device)

# %%
print("d_model:", my_model.tok_emb.embedding_dim)
print("n_heads:", my_model.encoders[0].attn.n_heads)
print("d_k:", my_model.encoders[0].attn.d_k)
# Out:
# d_model: 256
# n_heads: 4
# d_k: 64

# %%
loss_fn = nn.CrossEntropyLoss(ignore_index=PAD_ID)
optimizer = torch.optim.AdamW(my_model.parameters(), lr=3e-4)

EPOCHS = 20

for epoch in range(EPOCHS):
    my_model.train()
    total_loss = 0

    for src, tgt in train_loader:
        src = src.to(device)
        tgt = tgt.to(device)

        tgt_in = tgt[:, :-1]
        tgt_out = tgt[:, 1:]

        logits = my_model(src, tgt_in)

        loss = loss_fn(
            logits.reshape(-1, logits.size(-1)),
            tgt_out.reshape(-1)
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print("Epoch # {}, Train Loss Value = {}, Perplexity = {}".format(
        epoch + 1, total_loss / len(train_loader), math.exp(total_loss / len(train_loader))
    ))
# Out:
# Epoch # 1, Train Loss Value = 7.188423224335886, Perplexity = 1324.0138859715635
# Epoch # 2, Train Loss Value = 6.532391608446494, Perplexity = 687.0393773744576
# Epoch # 3, Train Loss Value = 6.02761598930505, Perplexity = 414.72514072729433
# Epoch # 4, Train Loss Value = 5.544588920257101, Perplexity = 255.8493821245312
# Epoch # 5, Train Loss Value = 5.067313994484386, Perplexity = 158.74735789995077
# Epoch # 6, Train Loss Value = 4.575680712630466, Perplexity = 97.09410983371083
# Epoch # 7, Train Loss Value = 4.085420188319181, Perplexity = 59.46691980737294
# Epoch # 8, Train Loss Value = 3.5909170373646235, Perplexity = 36.26731916829141
# Epoch # 9, Train Loss Value = 3.096351748682073, Perplexity = 22.117115121396534
# Epoch # 10, Train Loss Value = 2.612100699852253, Perplexity = 13.627648402865157
# Epoch # 11, Train Loss Value = 2.1418086167039543, Perplexity = 8.514823763371739
# Epoch # 12, Train Loss Value = 1.6997189613137664, Perplexity = 5.472409216897158
# Epoch # 13, Train Loss Value = 1.2928583927994943, Perplexity = 3.643185341512849
# Epoch # 14, Train Loss Value = 0.9386117880828536, Perplexity = 2.556430087187104
# Epoch # 15, Train Loss Value = 0.6632635329646626, Perplexity = 1.9411169075782542
# Epoch # 16, Train Loss Value = 0.44205562387846437, Perplexity = 1.5559022833466702
# Epoch # 17, Train Loss Value = 0.28250871907020436, Perplexity = 1.326453340486128
# Epoch # 18, Train Loss Value = 0.1621175081222907, Perplexity = 1.175998422568584
# Epoch # 19, Train Loss Value = 0.09836302954575112, Perplexity = 1.1033632658761434
# Epoch # 20, Train Loss Value = 0.06061081502629423, Perplexity = 1.0624853303867459

# %%
def translate_my_model(sentence, max_len=50, beam_size=5):
    my_model.eval()
    device = next(my_model.parameters()).device

    src = [sp.bos_id()] + sp.encode(sentence, out_type=int) + [sp.eos_id()]
    src = src[:MAX_LEN]
    src += [PAD_ID] * (MAX_LEN - len(src))
    src = torch.tensor(src).unsqueeze(0).to(device)

    beams = [([sp.bos_id()], 0.0)]

    for _ in range(max_len):
        new_beams = []

        for tokens, score in beams:
            if tokens[-1] == EOS_ID:
                new_beams.append((tokens, score))
                continue

            tgt = torch.tensor(tokens).unsqueeze(0).to(device)

            with torch.no_grad():
                logits = my_model(src, tgt)
                log_probs = torch.log_softmax(logits[0, -1], dim=-1)

            topk = torch.topk(log_probs, beam_size)

            for i in range(beam_size):
                new_tokens = tokens + [topk.indices[i].item()]
                new_score = score + topk.values[i].item()
                new_beams.append((new_tokens, new_score))

        beams = sorted(new_beams, key=lambda x: x[1], reverse=True)[:beam_size]

    best_tokens = beams[0][0]
    return sp.decode(best_tokens[1:-1])

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = "Helsinki-NLP/opus-mt-en-de"
marian_tokenizer = MarianTokenizer.from_pretrained(model_name)
marian_model = MarianMTModel.from_pretrained(model_name)
# Out:
# /home/anas/.mldsgenai/lib/python3.12/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
def translate_marian(sentence):
    inputs = marian_tokenizer(sentence, return_tensors="pt", truncation=True)
    outputs = marian_model.generate(
        **inputs,
        num_beams=6,
        length_penalty=1.1,
        early_stopping=True
    )
    return marian_tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
s = "This project demonstrates a transformer based translation model."

print("MY TRANSFORMER:")
print(translate_my_model(s))

print("\nMARIAN TRANSFORMER:")
print(translate_marian(s))
# Out:
# MY TRANSFORMER:
# Die medizinernizund beseit ⁇ glicht ein S.
#
# MARIAN TRANSFORMER:
# Dieses Projekt zeigt ein transformatorbasiertes Übersetzungsmodell.
