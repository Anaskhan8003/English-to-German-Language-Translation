# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
import torch
import os
import sentencepiece as spm
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import math

# %%
os.environ["HF_DATASETS_ALLOW_CODE"] = "1"

# %%
dataset = load_dataset("opus100","de-en")

# %%
src_lang = "en"
target_lang = "de"

# %%
train_data = dataset["train"].shuffle(seed=42).select(range(100_000))
val_data = dataset["validation"]
test_data = dataset["test"]

# %%
train_data
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 100000
# })

# %%
print(train_data[0]["translation"]["en"])
print(train_data[0]["translation"]["de"])
# Out:
# [{"Id":"52281fa3-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa5-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa6-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa7-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":2},{"Id":"52281fa8-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":1},{"Id":"3711adf0-87d6-4615-aed3-abc0671c8b85","Index":0,"Count":1},{"Id":"a8696682-c170-4f76-a6f2-92aaa7276042","Index":0,"Count":1}]
# [{"Id":"52281fa3-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa5-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa6-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa7-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":2},{"Id":"52281fa8-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":1},{"Id":"3711adf0-87d6-4615-aed3-abc0671c8b85","Index":0,"Count":1},{"Id":"a8696682-c170-4f76-a6f2-92aaa7276042","Index":0,"Count":1}]

# %%
def get_lengths(example):
    src = example["translation"][src_lang]
    tgt = example["translation"][target_lang]
    return {
        "src_len": len(src.split()),
        "tgt_len": len(tgt.split())
    }
lengths = train_data.map(get_lengths)

# %%
lengths[0]
# Out:
# {'translation': {'de': '[{"Id":"52281fa3-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa5-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa6-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa7-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":2},{"Id":"52281fa8-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":1},{"Id":"3711adf0-87d6-4615-aed3-abc0671c8b85","Index":0,"Count":1},{"Id":"a8696682-c170-4f76-a6f2-92aaa7276042","Index":0,"Count":1}]',
#   'en': '[{"Id":"52281fa3-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa5-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa6-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":0},{"Id":"52281fa7-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":2},{"Id":"52281fa8-51ca-11d1-8f14-00a02427d15e","Index":0,"Count":1},{"Id":"3711adf0-87d6-4615-aed3-abc0671c8b85","Index":0,"Count":1},{"Id":"a8696682-c170-4f76-a6f2-92aaa7276042","Index":0,"Count":1}]'},
#  'src_len': 1,
#  'tgt_len': 1}

# %%
print(train_data[1]["translation"]["en"])
# Out:
# 1 x Spider Straps System f...

# %%
def is_valid_text(example):
    src = example["translation"][src_lang]
    tgt = example["translation"][target_lang]

    if src.strip().startswith("[{") or tgt.strip().startswith("[{"):
        return False

    if len(src.split()) < 3 or len(tgt.split()) < 3:
        return False

    return True

# %%
clean_train = train_data.filter(is_valid_text)

# %%
print(clean_train[0]["translation"]["en"])
print(clean_train[0]["translation"]["de"])
# Out:
# 1 x Spider Straps System f...
# 1 x Metall-Helmhalterung f...

# %%
df = clean_train.to_pandas()

# %%
df["en"] = df["translation"].apply(lambda x: x["en"])
df["de"] = df["translation"].apply(lambda x: x["de"])

# %%
df = df.drop(columns=["translation"])

# %%
df
# Out:
#                                                       en  \
# 0                          1 x Spider Straps System f...
# 1                                       Leave a message.
# 2                                But you take the night.
# 3                              Weekly rate from: EUR 750
# 4                            Stop with the coffee, okay?
# ...                                                  ...
# 83226  Rare, wild flowers include a species of red wi...
# 83227  Look at him over there having lunch with his dad.
# 83228  6. In view of the above considerations, the cl...
# 83229                                   No sign of Zorn.
# 83230           That's Long John Peter to you, Porthole.
#
#                                                       de
# 0                          1 x Metall-Helmhalterung f...
# 1                             Hinterlasst 'ne Nachricht.
# 2                       Aber schlafen Sie einmal drüber.
# 3                              Wochenpreis ab: EUR 1.070
# 4                          Hör mit dem Kaffee auf, okay?
# ...                                                  ...
# 83226  Seltene, wilde Blumen einschließlich eine Art ...
# 83227         Guck nur, wie er da mit seinem Vater isst.
# 83228  13. Die Kammer kommt deshalb zum Schluss, dass...
# 83229                           Kein Anzeichen von Zorn.
# 83230           Für dich Long John Peter, du Hafen-Hure!
#
# [83231 rows x 2 columns]

# %%
df_sample = df.sample(30000, random_state=42)

df_sample["en"].to_csv("train.en", index=False, header=False)
df_sample["de"].to_csv("train.de", index=False, header=False)

# %%
spm.SentencePieceTrainer.train(
    input="train.en,train.de",
    model_prefix="bpe_en_de",
    vocab_size=8000,
    model_type="bpe",
    character_coverage=1.0,
    bos_id=1,
    eos_id=2,
    unk_id=0,
    pad_id=3
)
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: train.en
#   input: train.de
#   input_format:
#   model_prefix: bpe_en_de
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: 3
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: train.en
# trainer_interface.cc(186) LOG(INFO) Loading corpus: train.de
# trainer_interface.cc(411) LOG(INFO) Loaded all 60000 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=5020510
# trainer_interface.cc(562) LOG(INFO) Alphabet size=502
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 60000 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 60000
# trainer_interface.cc(611) LOG(INFO) Done! 140460
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=92369 min_freq=164
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26515 size=20 all=6709 active=2464 piece=or
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14516 size=40 all=8109 active=3864 piece=▁n
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10130 size=60 all=9540 active=5295 piece=▁and
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8548 size=80 all=10748 active=6503 piece=im
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6298 size=100 all=12486 active=8241 piece=am
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6253 min_freq=558
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5309 size=120 all=14562 active=2915 piece=ct
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4285 size=140 all=16263 active=4616 piece=ver
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3551 size=160 all=18050 active=6403 piece=▁al
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3063 size=180 all=19285 active=7638 piece=ill
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2668 size=200 all=20341 active=8694 piece=ann
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2643 min_freq=453
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2376 size=220 all=22034 active=2608 piece=af
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2141 size=240 all=23553 active=4127 piece=pe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1950 size=260 all=24913 active=5487 piece=▁als
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1785 size=280 all=25861 active=6435 piece=och
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1660 size=300 all=27169 active=7743 piece=▁from
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1654 min_freq=317
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1495 size=320 all=28423 active=2612 piece=ok
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1386 size=340 all=29692 active=3881 piece=▁dass
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1270 size=360 all=30876 active=5065 piece=ön
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1197 size=380 all=31797 active=5986 piece=etz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1124 size=400 all=33295 active=7484 piece=ore
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1124 min_freq=241
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1036 size=420 all=34396 active=2694 piece=are
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=965 size=440 all=35821 active=4119 piece=201
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=918 size=460 all=36897 active=5195 piece=erv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=862 size=480 all=37878 active=6176 piece=),
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=831 size=500 all=38819 active=7117 piece=imm
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=831 min_freq=193
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=806 size=520 all=39636 active=2694 piece=▁Te
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=773 size=540 all=40561 active=3619 piece=lichen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=749 size=560 all=41325 active=4383 piece=schaft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=709 size=580 all=42341 active=5399 piece=▁(1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=676 size=600 all=42974 active=6032 piece=elt
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=676 min_freq=165
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=651 size=620 all=43706 active=2796 piece=ree
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=628 size=640 all=44305 active=3395 piece=▁wurde
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=604 size=660 all=45092 active=4182 piece=ke
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=587 size=680 all=45724 active=4814 piece=act
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=568 size=700 all=46463 active=5553 piece=▁if
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=568 min_freq=144
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=551 size=720 all=47217 active=3074 piece=etzt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=527 size=740 all=47833 active=3690 piece=▁dis
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=508 size=760 all=48385 active=4242 piece=alt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=494 size=780 all=49064 active=4921 piece=▁Komm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=480 size=800 all=49772 active=5629 piece=olit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=478 min_freq=129
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=462 size=820 all=50374 active=3058 piece=hm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=449 size=840 all=51144 active=3828 piece=ierung
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=438 size=860 all=51606 active=4290 piece=▁shall
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=427 size=880 all=52179 active=4863 piece=▁dich
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=414 size=900 all=52743 active=5427 piece=/201
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=413 min_freq=116
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=401 size=920 all=53273 active=3146 piece=▁hin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=391 size=940 all=54015 active=3888 piece=fter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=382 size=960 all=54596 active=4469 piece=▁sow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=376 size=980 all=55081 active=4954 piece=glie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=367 size=1000 all=55756 active=5629 piece=pos
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=367 min_freq=107
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=360 size=1020 all=56335 active=3317 piece=▁Arbeit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=352 size=1040 all=57072 active=4054 piece=änd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=347 size=1060 all=57749 active=4731 piece=kommen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=340 size=1080 all=58395 active=5377 piece=arm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=334 size=1100 all=58976 active=5958 piece=min
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=334 min_freq=98
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=329 size=1120 all=59595 active=3488 piece=▁gegen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=324 size=1140 all=59816 active=3709 piece=▁gr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=318 size=1160 all=60251 active=4144 piece=ower
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=311 size=1180 all=60805 active=4698 piece=▁make
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=305 size=1200 all=61270 active=5163 piece=▁son
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=305 min_freq=91
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=300 size=1220 all=61604 active=3393 piece=hne
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=295 size=1240 all=62163 active=3952 piece=arge
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=290 size=1260 all=62681 active=4470 piece=▁wür
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=284 size=1280 all=63139 active=4928 piece=gend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=278 size=1300 all=63560 active=5349 piece=▁end
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=278 min_freq=86
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=275 size=1320 all=64052 active=3651 piece=▁fl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=273 size=1340 all=64597 active=4196 piece=▁Wie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=268 size=1360 all=64988 active=4587 piece=leg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=264 size=1380 all=65300 active=4899 piece=▁room
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=258 size=1400 all=65832 active=5431 piece=▁machen
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=257 min_freq=81
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=251 size=1420 all=66313 active=3772 piece=/-/-
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=246 size=1440 all=66847 active=4306 piece=hor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=243 size=1460 all=67352 active=4811 piece=▁fol
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=239 size=1480 all=67833 active=5292 piece=▁Teil
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=236 size=1500 all=68283 active=5742 piece=▁Wer
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=236 min_freq=75
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=232 size=1520 all=68647 active=3762 piece=▁high
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=228 size=1540 all=68935 active=4050 piece=hed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=226 size=1560 all=69281 active=4396 piece=▁page
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=222 size=1580 all=69732 active=4847 piece=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=220 size=1600 all=70229 active=5344 piece=▁Entw
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=220 min_freq=71
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=217 size=1620 all=70605 active=3880 piece=mittel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=213 size=1640 all=71077 active=4352 piece=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=211 size=1660 all=71642 active=4917 piece=tschaft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=208 size=1680 all=72019 active=5294 piece=▁hal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=205 size=1700 all=72447 active=5722 piece=icherheit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=204 min_freq=67
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=201 size=1720 all=72981 active=4144 piece=▁su
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=199 size=1740 all=73450 active=4613 piece=▁Eur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=197 size=1760 all=73830 active=4993 piece=▁ausge
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=194 size=1780 all=74190 active=5353 piece=▁ja
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=192 size=1800 all=74652 active=5815 piece=▁2008
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=192 min_freq=63
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=189 size=1820 all=74995 active=4065 piece=ilt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=188 size=1840 all=75290 active=4360 piece=legen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=186 size=1860 all=75710 active=4780 piece=▁glaub
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=184 size=1880 all=76168 active=5238 piece=▁cre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=181 size=1900 all=76477 active=5547 piece=amen
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=181 min_freq=60
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=179 size=1920 all=76799 active=4121 piece=raft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=175 size=1940 all=77216 active=4538 piece=tegr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=173 size=1960 all=77683 active=5005 piece=▁2012
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=172 size=1980 all=77893 active=5215 piece=▁Germany
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=170 size=2000 all=78374 active=5696 piece=asser
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=170 min_freq=57
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=168 size=2020 all=78717 active=4225 piece=reakfast
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=166 size=2040 all=79043 active=4551 piece=öglichkeit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=164 size=2060 all=79400 active=4908 piece=▁Amer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=162 size=2080 all=79708 active=5216 piece=▁ide
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=161 size=2100 all=79923 active=5431 piece=eiten
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=161 min_freq=55
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=159 size=2120 all=80351 active=4402 piece=ought
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=157 size=2140 all=80670 active=4721 piece=gang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=155 size=2160 all=81029 active=5080 piece=licher
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=2180 all=81387 active=5438 piece=▁40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=2200 all=81834 active=5885 piece=▁kl
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=151 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=2220 all=82165 active=4409 piece=▁Spe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=2240 all=82665 active=4909 piece=html
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=2260 all=82973 active=5217 piece=▁call
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=2280 all=83399 active=5643 piece=gether
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=2300 all=83728 active=5972 piece=ätz
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=143 min_freq=50
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=2320 all=84166 active=4601 piece=▁mar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=2340 all=84534 active=4969 piece=ames
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=139 size=2360 all=84819 active=5254 piece=▁voll
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=137 size=2380 all=85129 active=5564 piece=bo
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=2400 all=85763 active=6198 piece=▁konn
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=136 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=2420 all=85988 active=4510 piece=▁Direct
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=2440 all=86272 active=4794 piece=OM
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=2460 all=86678 active=5200 piece=mbH
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=131 size=2480 all=87056 active=5578 piece=UN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=2500 all=87370 active=5892 piece=nell
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=130 min_freq=46
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=2520 all=87638 active=4612 piece=▁means
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=2540 all=88013 active=4987 piece=▁GmbH
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=2560 all=88252 active=5226 piece=▁groß
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=2580 all=88521 active=5495 piece=▁Juli
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=2600 all=88650 active=5624 piece=▁million
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=124 min_freq=45
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=2620 all=89086 active=4868 piece=▁Bel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=2640 all=89447 active=5229 piece=▁akt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=2660 all=89697 active=5479 piece=ergie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=2680 all=90051 active=5833 piece=▁Hol
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=2700 all=90365 active=6147 piece=▁gre
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=119 min_freq=43
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=2720 all=90672 active=4813 piece=schein
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=117 size=2740 all=90861 active=5002 piece=▁read
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=2760 all=91066 active=5207 piece=ibility
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=2780 all=91317 active=5458 piece=▁hätte
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=2800 all=91572 active=5713 piece=AB
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=113 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=2820 all=91881 active=4852 piece=▁private
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=2840 all=92156 active=5127 piece=▁result
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=2860 all=92504 active=5475 piece=▁stre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=2880 all=93104 active=6075 piece=ides
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=2900 all=93483 active=6454 piece=imal
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=109 min_freq=40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=108 size=2920 all=93723 active=4888 piece=prü
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=2940 all=93913 active=5078 piece=Mr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=2960 all=94192 active=5357 piece=▁question
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=106 size=2980 all=94432 active=5597 piece=▁account
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=3000 all=94759 active=5924 piece=▁compet
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=105 min_freq=39
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=3020 all=95010 active=4983 piece=▁plan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=3040 all=95288 active=5261 piece=▁Cent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=3060 all=95616 active=5589 piece=read
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3080 all=95877 active=5850 piece=▁Oh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3100 all=96148 active=6121 piece=▁environment
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=100 min_freq=38
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=3120 all=96478 active=5136 piece=▁Haupt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=3140 all=96715 active=5373 piece=▁Zahl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=3160 all=96975 active=5633 piece=▁wr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=3180 all=97221 active=5879 piece=.8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=3200 all=97640 active=6298 piece=halts
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=97 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=3220 all=97843 active=5044 piece=5"
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=3240 all=98045 active=5246 piece=▁success
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=3260 all=98354 active=5555 piece=rieden
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=3280 all=98615 active=5816 piece=ferenz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=3300 all=98923 active=6124 piece=▁70
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=93 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=3320 all=99154 active=5165 piece=▁inform
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=3340 all=99423 active=5434 piece=▁paar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=3360 all=99640 active=5651 piece=▁32
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=3380 all=99758 active=5769 piece=▁schön
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=3400 all=100051 active=6062 piece=index
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=90 min_freq=35
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=3420 all=100173 active=5118 piece=▁contact
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=3440 all=100472 active=5417 piece=achte
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=3460 all=100692 active=5637 piece=▁understand
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=3480 all=100927 active=5872 piece=▁Einz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=3500 all=101183 active=6128 piece=▁$
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=87 min_freq=34
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=3520 all=101476 active=5326 piece=ienten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=3540 all=101818 active=5668 piece=▁PC
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=3560 all=102033 active=5883 piece=▁Allah
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=3580 all=102275 active=6125 piece=hof
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=3600 all=102589 active=6439 piece=▁Mont
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=85 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=3620 all=102638 active=5163 piece=OS
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=3640 all=103032 active=5557 piece=▁adv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=3660 all=103216 active=5741 piece=▁Erfahr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=3680 all=103353 active=5878 piece=▁gute
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=3700 all=103448 active=5973 piece=mm
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=82 min_freq=32
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=3720 all=103738 active=5440 piece=▁benef
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=3740 all=104063 active=5765 piece=ms
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=3760 all=104359 active=6061 piece=▁wait
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=3780 all=104473 active=6175 piece=TER
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=3800 all=104682 active=6384 piece=▁deter
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=80 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=79 size=3820 all=104920 active=5468 piece=▁Ele
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=79 size=3840 all=105110 active=5658 piece=▁einzel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=3860 all=105351 active=5899 piece=inner
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=3880 all=105503 active=6051 piece=▁meisten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=3900 all=105877 active=6425 piece=aving
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=77 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=3920 all=105998 active=5407 piece=▁europäischen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=3940 all=106325 active=5734 piece=ielle
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=3960 all=106503 active=5912 piece=DF
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=3980 all=106819 active=6228 piece=▁hold
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=4000 all=107056 active=6465 piece=ara
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=74 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=4020 all=107303 active=5569 piece=▁kid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=4040 all=107424 active=5690 piece=▁kannst
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=4060 all=107584 active=5850 piece=abor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=4080 all=107877 active=6143 piece=▁darf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=4100 all=107966 active=6232 piece=▁Version
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=73 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=4120 all=108161 active=5594 piece=error
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=4140 all=108261 active=5694 piece=▁network
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=4160 all=108528 active=5961 piece=▁age
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=4180 all=108650 active=6083 piece=▁amount
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=4200 all=108833 active=6266 piece=aper
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=70 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=4220 all=109024 active=5620 piece=▁Raum
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=4240 all=109049 active=5645 piece=▁training
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=4260 all=109412 active=6008 piece=▁fav
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=4280 all=109543 active=6139 piece=▁members
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=4300 all=109807 active=6403 piece=▁Rad
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=68 min_freq=28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=4320 all=110031 active=5694 piece=▁team
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=4340 all=110141 active=5804 piece=▁jemand
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=4360 all=110378 active=6041 piece=▁dra
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=4380 all=110488 active=6151 piece=▁separ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=4400 all=110693 active=6356 piece=:06
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=66 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=4420 all=111017 active=5816 piece=itzen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=4440 all=111175 active=5974 piece=▁Dinge
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=4460 all=111292 active=6091 piece=ags
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=4480 all=111651 active=6450 piece=▁fall
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=4500 all=111755 active=6554 piece=▁Millionen
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=65 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=4520 all=112215 active=6047 piece=icro
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=4540 all=112419 active=6251 piece=▁join
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=4560 all=112502 active=6334 piece=▁especially
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=4580 all=112814 active=6646 piece=mail
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=4600 all=112995 active=6827 piece=▁easy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=63 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=4620 all=113088 active=5743 piece=▁Portug
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=4640 all=113285 active=5940 piece=▁"[
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=4660 all=113585 active=6240 piece=nesday
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=4680 all=113645 active=6300 piece=10%
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=4700 all=113998 active=6653 piece=▁15.
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=61 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=4720 all=114165 active=5863 piece=▁nice
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=4740 all=114220 active=5918 piece=▁sowohl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=4760 all=114453 active=6151 piece=▁4,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=4780 all=114719 active=6417 piece=.2015
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=4800 all=114924 active=6622 piece=▁Court
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=60 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=4820 all=115019 active=5842 piece=▁Ländern
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=4840 all=115195 active=6018 piece=From
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=4860 all=115430 active=6253 piece=ology
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=4880 all=115543 active=6366 piece=ierungen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=4900 all=115672 active=6495 piece=:39
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=58 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=4920 all=116083 active=6155 piece=▁22,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=4940 all=116238 active=6310 piece=▁wife
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=4960 all=116307 active=6379 piece=schließlich
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=4980 all=116701 active=6773 piece=most
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=5000 all=116931 active=7003 piece=▁gran
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=5020 all=117039 active=5950 piece=▁depend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=5040 all=117166 active=6077 piece=-10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=5060 all=117461 active=6372 piece=▁28,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=5080 all=117641 active=6552 piece=▁Peter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=5100 all=117805 active=6716 piece=.""
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=55 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=5120 all=118071 active=6153 piece=acity
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=5140 all=118249 active=6331 piece=▁plann
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=5160 all=118294 active=6376 piece=▁operation
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=5180 all=118548 active=6630 piece=top
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=5200 all=118785 active=6867 piece=ledge
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=54 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=5220 all=118882 active=6032 piece=▁often
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=5240 all=118961 active=6111 piece=sterreich
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=5260 all=119244 active=6394 piece=ilar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=5280 all=119444 active=6594 piece=▁0.01
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=5300 all=119556 active=6706 piece=▁effic
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=5320 all=119619 active=6038 piece=▁zuständ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=5340 all=119765 active=6184 piece=:24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=5360 all=120051 active=6470 piece=immel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=5380 all=120188 active=6607 piece=▁cross
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=5400 all=120300 active=6719 piece=partments
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=52 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=5420 all=120560 active=6271 piece=Vor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=5440 all=120841 active=6552 piece=▁Mot
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=5460 all=120993 active=6704 piece=ritten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=5480 all=121090 active=6801 piece=▁solche
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=5500 all=121424 active=7135 piece=:51
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=50 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=5520 all=121708 active=6318 piece=▁Max
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=5540 all=121823 active=6433 piece=▁Ihrem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=5560 all=121866 active=6476 piece=▁greater
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=5580 all=121943 active=6553 piece=▁©
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=5600 all=122214 active=6824 piece=▁Est
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=49 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=5620 all=122436 active=6323 piece=▁Schn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=5640 all=122585 active=6472 piece=richten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=5660 all=122623 active=6510 piece=▁Dokument
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=5680 all=123028 active=6915 piece=zif
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=5700 all=123224 active=7111 piece=▁rat
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=48 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=5720 all=123375 active=6302 piece=▁fell
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=5740 all=123450 active=6377 piece=▁stellt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=5760 all=123474 active=6401 piece=▁Startseite
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=5780 all=123850 active=6777 piece=iker
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=5800 all=124030 active=6957 piece=ausch
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=47 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=5820 all=124128 active=6284 piece=/04/17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=5840 all=124223 active=6379 piece=▁levels
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=5860 all=124235 active=6391 piece=▁Jahrhunder
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5880 all=124599 active=6755 piece=ila
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5900 all=124841 active=6997 piece=▁key
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=46 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5920 all=125021 active=6418 piece=▁bank
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5940 all=125122 active=6519 piece=▁black
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5960 all=125184 active=6581 piece=▁approx
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=5980 all=125242 active=6639 piece=▁Erfahrung
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=6000 all=125438 active=6835 piece=cep
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=45 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=6020 all=125658 active=6484 piece=▁lar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=6040 all=125822 active=6648 piece=▁gehe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=6060 all=125930 active=6756 piece=▁hotels
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6080 all=125962 active=6788 piece=TA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6100 all=126291 active=7117 piece=▁Aud
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=44 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6120 all=126492 active=6508 piece=riffe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6140 all=126596 active=6612 piece=coming
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6160 all=126704 active=6720 piece=▁Dieser
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=6180 all=126706 active=6722 piece=▁Wahrheit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=6200 all=126829 active=6845 piece=▁;
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=43 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=6220 all=127174 active=6683 piece=iens
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=6240 all=127337 active=6846 piece=nungs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=6260 all=127447 active=6956 piece=▁shows
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=6280 all=127499 active=7008 piece=▁similar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=6300 all=127592 active=7101 piece=ira
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=42 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=6320 all=127810 active=6581 piece=▁Neu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=6340 all=127920 active=6691 piece=▁habt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=6360 all=128008 active=6779 piece=▁birth
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=6380 all=128038 active=6809 piece=▁display
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6400 all=128169 active=6940 piece=(1)
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6420 all=128402 active=6617 piece=lant
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6440 all=128525 active=6740 piece=attet
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6460 all=128645 active=6860 piece=fforts
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6480 all=128769 active=6984 piece=führten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6500 all=128805 active=7020 piece=▁efforts
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=6520 all=128839 active=6475 piece=▁principle
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6540 all=129032 active=6668 piece=tty
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6560 all=129254 active=6890 piece=▁Bek
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6580 all=129451 active=7087 piece=▁East
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6600 all=129514 active=7150 piece=urance
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=40 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6620 all=129566 active=6523 piece=▁anders
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=6640 all=129571 active=6528 piece=▁Saturday
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6660 all=129756 active=6713 piece=box
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6680 all=129979 active=6936 piece=▁hy
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6700 all=130212 active=7169 piece=▁Top
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=39 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6720 all=130394 active=6688 piece=▁Orig
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6740 all=130490 active=6784 piece=▁Health
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6760 all=130545 active=6839 piece=▁parties
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=6780 all=130557 active=6851 piece=▁Informations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6800 all=130868 active=7162 piece=zub
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6820 all=131119 active=6777 piece=uted
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6840 all=131245 active=6903 piece=räfte
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6860 all=131367 active=7025 piece=employ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6880 all=131453 active=7111 piece=▁klein
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6900 all=131537 active=7195 piece=▁credit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6920 all=131569 active=6608 piece=▁challen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=6940 all=131609 active=6648 piece=▁unabhäng
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=6960 all=131757 active=6796 piece=bek
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=6980 all=132017 active=7056 piece=upts
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=7000 all=132172 active=7211 piece=endes
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=37 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=7020 all=132282 active=6698 piece=▁guid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=7040 all=132458 active=6874 piece=▁ersch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=7060 all=132514 active=6930 piece=▁erster
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=7080 all=132547 active=6963 piece=▁zweiten
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7100 all=132701 active=7117 piece=zz
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7120 all=133010 active=6919 piece=▁Erd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7140 all=133116 active=7025 piece=▁Fund
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7160 all=133223 active=7132 piece=▁Check
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7180 all=133292 active=7201 piece=▁Chance
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7200 all=133323 active=7232 piece=▁spezie
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7220 all=133343 active=6684 piece=▁benefits
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=7240 all=133337 active=6678 piece=▁Erzeugnisse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7260 all=133499 active=6840 piece=vey
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7280 all=133703 active=7044 piece=▁Mex
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7300 all=133837 active=7178 piece=▁code
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=35 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7320 all=133903 active=6756 piece=▁agree
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7340 all=133957 active=6810 piece=▁couldn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7360 all=133953 active=6806 piece=▁registr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=7380 all=133971 active=6824 piece=▁einschließlich
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=7400 all=134178 active=7031 piece=ais
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=34 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=7420 all=134370 active=6880 piece=ften
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=7440 all=134567 active=7077 piece=▁Hat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=7460 all=134688 active=7198 piece=▁Doch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=7480 all=134754 active=7264 piece=verlag
# trainer_interface.cc(689) LOG(INFO) Saving model: bpe_en_de.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: bpe_en_de.vocab

# %%
sp = spm.SentencePieceProcessor()
sp.load("bpe_en_de.model")
# Out:
# True

# %%
encoded_data_dict = {
    "src_en_ids": [],
    "tgt_de_ids": []
}

max_src_len = 0
max_tgt_len = 0
for _, row in df.iterrows():
    en_text = row["en"]
    de_text = row["de"]

    en_ids = [sp.bos_id()] + sp.encode(en_text, out_type=int) + [sp.eos_id()]
    de_ids = [sp.bos_id()] + sp.encode(de_text, out_type=int) + [sp.eos_id()]

    encoded_data_dict["src_en_ids"].append(en_ids)
    encoded_data_dict["tgt_de_ids"].append(de_ids)

    if len(en_ids) > max_src_len:
        max_src_len = len(en_ids)

    if len(de_ids) > max_tgt_len:
        max_tgt_len = len(de_ids)

# %%
print(encoded_data_dict["src_en_ids"][0])
print(encoded_data_dict["tgt_de_ids"][0])
# Out:
# [1, 65, 1236, 580, 958, 2294, 3624, 2524, 33, 289, 2]
# [1, 65, 1236, 4074, 234, 7530, 7547, 86, 7512, 402, 85, 62, 33, 289, 2]

# %%
print(sp.decode(encoded_data_dict["src_en_ids"][0][1:-1]))
print(sp.decode(encoded_data_dict["tgt_de_ids"][0][1:-1]))
# Out:
# 1 x Spider Straps System f...
# 1 x Metall-Helmhalterung f...

# %%
print("Max EN length:", max_src_len)
print("Max DE length:", max_tgt_len)
# Out:
# Max EN length: 2593
# Max DE length: 3445

# %%
PAD_ID = sp.pad_id()
BOS_ID = sp.bos_id()
EOS_ID = sp.eos_id()

def process_sequence(seq, max_len):
    if len(seq) > max_len:
        seq = seq[:max_len]
        seq[-1] = EOS_ID 

    if len(seq) < max_len:
        seq = seq + [PAD_ID] * (max_len - len(seq))

    return seq

# %%
MAX_LEN = 512
encoded_data_dict["src_en_ids"] = [
    process_sequence(seq, MAX_LEN)
    for seq in encoded_data_dict["src_en_ids"]
]

encoded_data_dict["tgt_de_ids"] = [
    process_sequence(seq, MAX_LEN)
    for seq in encoded_data_dict["tgt_de_ids"]
]

# %%
print(len(encoded_data_dict["src_en_ids"][0]))
print(len(encoded_data_dict["tgt_de_ids"][0]))
# Out:
# 512
# 512

# %%
print(encoded_data_dict["src_en_ids"][0][:10])
print(encoded_data_dict["src_en_ids"][0][-10:])
# Out:
# [1, 65, 1236, 580, 958, 2294, 3624, 2524, 33, 289]
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
class SingleAttentionHead(torch.nn.Module):

    def __init__(self, query_key_embedding_dim, value_embedding_dim,
                 sha_dim, masked, is_dropout, dropout_probability):
        super().__init__()

        self.sha_dim = sha_dim
        self.masked = masked
        self.is_dropout = is_dropout

        self.query_projection_layer = torch.nn.Linear(
            query_key_embedding_dim, sha_dim, bias=False
        )
        self.key_projection_layer = torch.nn.Linear(
            query_key_embedding_dim, sha_dim, bias=False
        )
        self.value_projection_layer = torch.nn.Linear(
            value_embedding_dim, sha_dim, bias=False
        )

        self.softmax_activation = torch.nn.Softmax(dim=-1)

        if self.is_dropout:
            self.dropout = torch.nn.Dropout(p=dropout_probability)

    def forward(self, query_embedding, key_embedding, value_embedding):

        Q = self.query_projection_layer(query_embedding)
        K = self.key_projection_layer(key_embedding)
        V = self.value_projection_layer(value_embedding)

        scores = torch.matmul(Q, K.transpose(-2, -1)) / torch.sqrt(
            torch.tensor(self.sha_dim, dtype=torch.float32)
        )

        if self.masked:
            mask = torch.tril(torch.ones_like(scores))
            scores = scores.masked_fill(mask == 0, float("-inf"))

        attention_weights = self.softmax_activation(scores)

        if self.is_dropout:
            attention_weights = self.dropout(attention_weights)

        return torch.matmul(attention_weights, V)

# %%
class MultiHeadAttentionLayer(torch.nn.Module):

    def __init__(self, embedding_dim, num_attn_heads,
                 masked, is_dropout, dropout_probability):
        super().__init__()

        sha_dim = embedding_dim // num_attn_heads
        self.attn_heads = torch.nn.ModuleList([
            SingleAttentionHead(
                embedding_dim, embedding_dim,
                sha_dim, masked, is_dropout, dropout_probability
            )
            for _ in range(num_attn_heads)
        ])

        self.output_projection = torch.nn.Linear(
            embedding_dim, embedding_dim, bias=False
        )

        if is_dropout:
            self.dropout = torch.nn.Dropout(p=dropout_probability)
        self.is_dropout = is_dropout

    def forward(self, query, key, value):

        head_outputs = [
            head(query, key, value) for head in self.attn_heads
        ]

        concat = torch.cat(head_outputs, dim=-1)
        out = self.output_projection(concat)

        if self.is_dropout:
            out = self.dropout(out)

        return out

# %%
class EncoderLayer(torch.nn.Module):

    def __init__(self, model_dim, num_heads,
                 dropout_probability, ffn_dim):
        super().__init__()

        self.mha = MultiHeadAttentionLayer(
            model_dim, num_heads, False, True, dropout_probability
        )
        self.norm1 = torch.nn.LayerNorm(model_dim)

        self.ffn = torch.nn.Sequential(
            torch.nn.Linear(model_dim, ffn_dim),
            torch.nn.GELU(),
            torch.nn.Linear(ffn_dim, model_dim)
        )
        self.norm2 = torch.nn.LayerNorm(model_dim)
        self.dropout = torch.nn.Dropout(dropout_probability)

    def forward(self, x):

        x = self.norm1(x + self.mha(x, x, x))
        x = self.norm2(x + self.dropout(self.ffn(x)))

        return x

# %%
class DecoderLayer(torch.nn.Module):

    def __init__(self, model_dim, num_heads,
                 dropout_probability, ffn_dim):
        super().__init__()

        self.self_attn = MultiHeadAttentionLayer(
            model_dim, num_heads, True, True, dropout_probability
        )
        self.enc_dec_attn = MultiHeadAttentionLayer(
            model_dim, num_heads, False, True, dropout_probability
        )

        self.norm1 = torch.nn.LayerNorm(model_dim)
        self.norm2 = torch.nn.LayerNorm(model_dim)
        self.norm3 = torch.nn.LayerNorm(model_dim)

        self.ffn = torch.nn.Sequential(
            torch.nn.Linear(model_dim, ffn_dim),
            torch.nn.GELU(),
            torch.nn.Linear(ffn_dim, model_dim)
        )

        self.dropout = torch.nn.Dropout(dropout_probability)

    def forward(self, x, encoder_output):

        x = self.norm1(x + self.self_attn(x, x, x))
        x = self.norm2(x + self.enc_dec_attn(x, encoder_output, encoder_output))
        x = self.norm3(x + self.dropout(self.ffn(x)))

        return x

# %%
class TransformerTranslator(torch.nn.Module):

    def __init__(self, vocab_size, model_dim,
                 num_layers, num_heads,
                 ffn_dim, max_len):
        super().__init__()

        self.token_embedding = torch.nn.Embedding(vocab_size, model_dim)
        self.position_embedding = torch.nn.Embedding(max_len, model_dim)

        self.encoder_layers = torch.nn.ModuleList([
            EncoderLayer(model_dim, num_heads, 0.1, ffn_dim)
            for _ in range(num_layers)
        ])

        self.decoder_layers = torch.nn.ModuleList([
            DecoderLayer(model_dim, num_heads, 0.1, ffn_dim)
            for _ in range(num_layers)
        ])

        self.output_projection = torch.nn.Linear(model_dim, vocab_size)

    def forward(self, src_ids, tgt_ids):

        src_pos = torch.arange(src_ids.size(1)).to(src_ids.device)
        tgt_pos = torch.arange(tgt_ids.size(1)).to(tgt_ids.device)

        src = self.token_embedding(src_ids) + self.position_embedding(src_pos)
        tgt = self.token_embedding(tgt_ids) + self.position_embedding(tgt_pos)

        for enc in self.encoder_layers:
            src = enc(src)

        for dec in self.decoder_layers:
            tgt = dec(tgt, src)

        return self.output_projection(tgt)

# %%
def training_data_generator(encoded_data_dict, max_len):

    for src_ids, tgt_ids in zip(
        encoded_data_dict["src_en_ids"],
        encoded_data_dict["tgt_de_ids"]
    ):
        yield (
            torch.tensor(src_ids[:max_len]),
            torch.tensor(tgt_ids[:-1][:max_len]),
            torch.tensor(tgt_ids[1:][:max_len])
        )

# %%
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=sp.pad_id())
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

epochs = 20
X_src = torch.nn.utils.rnn.pad_sequence(
    [torch.tensor(x) for x in encoded_data_dict["src_en_ids"]],
    batch_first=True,
    padding_value=sp.pad_id()
)

Y_tgt = torch.nn.utils.rnn.pad_sequence(
    [torch.tensor(y) for y in encoded_data_dict["tgt_de_ids"]],
    batch_first=True,
    padding_value=sp.pad_id()
)

X_src = X_src[:, :512].cuda()
Y_tgt = Y_tgt[:, :512].cuda()
model.train()

for epoch in range(epochs):

    # shift target
    tgt_input  = Y_tgt[:, :-1]
    tgt_output = Y_tgt[:, 1:]

    # forward pass
    y_hat = model(X_src, tgt_input)

    # loss
    loss = loss_fn(
        y_hat.reshape(-1, y_hat.size(-1)),
        tgt_output.reshape(-1)
    )

    # backward
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    print(
        "Epoch # {}, Train Loss Value = {}".format(
            epoch + 1, loss.item()
        )
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 6
#       2 optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
#       4 epochs = 20
#       5 X_src = torch.nn.utils.rnn.pad_sequence(
# ----> 6     [torch.tensor(x) for x in encoded_data_dict["src_en_ids"]],
#       7     batch_first=True,
#       8     padding_value=sp.pad_id()
#       9 )
#      11 Y_tgt = torch.nn.utils.rnn.pad_sequence(
#      12     [torch.tensor(y) for y in encoded_data_dict["tgt_de_ids"]],
#      13     batch_first=True,
#      14     padding_value=sp.pad_id()
#      15 )
#      17 X_src = X_src[:, :512].cuda()
#
# KeyboardInterrupt:
